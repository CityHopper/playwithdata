# %%
from selenium import webdriver
driver = webdriver.Chrome('./chromedriver.exe')
url = 'https://www.visitjeju.net/kr/detail/list?menuId=DOM_000001718001000000&cate1cd=cate0000000002#p1&region2cd&pageSize=1125&sortListType=reviewcnt&viewType=thumb'
driver.get(url)

# %%
from bs4 import BeautifulSoup
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
prod_items = soup.select('dl.item_section')
len(prod_items)
# Out:
# 1119

# %%
prod_items
# Out:
# [<dl class="item_section"><dt class="item_top"><a href="/kr/detail/view?contentsid=CONT_000000000500477&amp;menuId=DOM_000001718001000000#p1"><span class="s_day">관광지</span><img alt="우도(해양도립공원) 대표이미지" class="" src="https://api.cdn.visitjeju.net/photomng/thumbnailpath/201804/30/e1c2f9e4-bf4c-488c-884c-5674f8d8b119.jpg"/><div class="score_area"><p class="score_count" style="width: 100%;">별점(5점만점에 5점)</p></div><p class="s_tit">우도(해양도립공원)</p><p class="s_theme">섬 속의 섬 &gt; 우도</p><p class="s_theme_tit">소가 누워있는 형상을 하고 있는 제주의 가장 큰 부속섬</p><p class="item_tag prev"><a>#섬속의섬</a> <a>#경관/포토</a> <a>#아이</a> </p><p class="item_tag next"> <a>#맑음</a></p></a></dt><dd class="item_count_area clear"><a href="javascript:void(0);"><p class="ico_type like"><span>좋아요</span><span class="count">112</span></p></a><a href="javascript:void(0);"><p class="ico_type zzim "><span>찜하기</span><span class="count">1,278</span></p></a><p class="ico_type review"><span>리뷰</span><span class="count">591</span></p><p class="item_c
# ...

# %%
from selenium import webdriver
driver = webdriver.Chrome('./chromedriver.exe')
driver.get('https://www.visitjeju.net/kr/detail/list?menuId=DOM_000001718001000000&cate1cd=cate0000000002#p1&region2cd&pageSize=1125&sortListType=reviewcnt&viewType=thumb')

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
prodList = soup.find_all("dl.item_section")
print(len(prodList))
# Out:
# 0

# %%
soup
# Out:
# <html data-n-head="lang" lang="ko"><head>
# <meta charset="utf-8" data-n-head="true"/><meta content="width=1200" data-n-head="true" name="viewport"/><meta content="website" data-hid="og:type" data-n-head="true" name="og:type"/><meta content="https://api.visitjeju.net/editorStore/file/201806/04/4b2e1446-3052-4ed4-82e7-086b3483cfaf.png" data-hid="og:image" data-n-head="true" name="og:image"/><meta content="muJClgGtbL" data-n-head="true" name="baidu-site-verification"/><meta content="fDNzLlrEdEshEo1aeSFFHnStL3KRvI2pZ2nVsexgXxo" data-n-head="true" name="google-site-verification"/><meta content="제주도 모든 여행지를 한 눈에…" data-hid="title" data-n-head="true" name="title"/><meta content="내가 가본 제주는 어디까지일까? 수많은 제주의 아름다운 여행지를 취향에 맞게 선택해보자.
# 368개의 크고 작은 오름을 비롯하여 눈 돌리면 어디에서나 마주치는 한라산 그리고 푸른 바다&amp;hellip;.
# ...

# %%
# -*- encoding:utf8 -*-
# Python version in the development environment 2.7.11
import os,sys,time

from selenium import webdriver

def non_js_execute(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.content)
    
    print(soup.find('p', {"class":"s_tit"}))
    r.close()

def js_execute(url):
    client = webdriver.PhantomJS(executable_path=r'C:\Users\CPBGame001\직장인을 위한 데이터 분석 실무 with 파이썬\phantomjs-2.1.1-windows\bin\phantomjs.exe')
    client.get(url)
    soup = BeautifulSoup(client.page_source)
    print(soup.find('p', {"class":"s_tit"}))

if __name__ == '__main__':
    URL = 'https://www.visitjeju.net/kr/detail/list?menuId=DOM_000001718001000000&cate1cd=cate0000000002#p1&region2cd&pageSize=1125&sortListType=reviewcnt&viewType=thumb'
    non_js_execute(URL)
    js_execute(URL)
# Out:
# None
# None

# %%
# 최초 발견한 태그만 검색
title = driver.find_element_by_tag_name('h3')
print (title.text)

# 모든 태그 검색
h3s = driver.find_elements_by_tag_name('h3')

for h3 in h3s:
    print (h3.text)
    
driver.quit()
